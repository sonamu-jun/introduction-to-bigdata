# %% [markdown]
# # 012-008. Comprehensions
#
# *Compress a simple “transform each value” loop only after the expanded loop is understood.*
#
# The conceptual foundation is developed in Collections and Iteration.

# %% [markdown]
# ## Method · Expanded Transformation Loop
#
# This loop creates a new list without changing `numbers`.

# %%
numbers = [1, 2, 3, 4, 5]
squares_with_loop = []

for number in numbers:
    squares_with_loop.append(number ** 2)

print(squares_with_loop)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## Implementation · Compact Transformations
#
# The expression `number ** 2` is evaluated once for each `number` in `numbers`.

# %%
squares = [number ** 2 for number in numbers]
print(squares)
print("Same result:", squares == squares_with_loop)
# Out:
# [1, 4, 9, 16, 25]
# Same result: True

# %% [markdown]
# ## Implementation · Filtered Comprehensions
#
# The condition comes last but is checked before the value is added to the result.

# %%
even_squares = [number ** 2 for number in numbers if number % 2 == 0]
print(even_squares)
# Out:
# [4, 16]

# %% [markdown]
# ## Implementation · Dictionary Comprehensions
#
# Placing `key: value` before `for` builds a dictionary instead of a list. Here, each number becomes a key and its square becomes the value.

# %%
square_lookup = {number: number ** 2 for number in numbers}
print(square_lookup)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# ### Interpretation · Dictionary Comprehensions
#
# Use a comprehension for one short transformation and at most one clear filter. Keep an ordinary loop when several steps, branches, or side effects would make the compact form harder to read.
#
# ### Independent Practice · Your Turn
#
# Test how the filter controls a comprehension's output. Change the condition from `number % 2 == 0` to `number % 3 == 0` and produce a table named `filtered_square_table` with columns `number` and `square`. Explain in one or two sentences how the new condition determines which rows appear.

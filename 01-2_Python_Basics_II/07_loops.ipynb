# %% [markdown]
# # Loops
#
# *Repeat one operation across a sequence and inspect the loop body and state after each iteration.*

# %% [markdown]
# ## Value Iteration
#
# A `for` loop assigns each item from an iterable to the loop variable in sequence. Indentation marks the block that repeats.

# %% [markdown]
# ## Result Accumulation and Augmented Assignment
#
# An accumulator is initialized before a loop and updated during each iteration. Augmented assignment such as `+=` combines an operation and reassignment.

# %% [markdown]
# ## Position Tracking and Paired Iteration
#
# `enumerate()` supplies an item together with its position. `zip()` pairs items from several iterables by position and stops when the shortest iterable is exhausted. Multiple loop variables can unpack the resulting pairs.

# %% [markdown]
# ## Counting with `range()`
#
# `range(start, stop)` produces integers from the start value up to, but not including, the stop value. A `for` loop is appropriate when the number of repetitions is known.

# %% [markdown]
# ## Condition-Controlled Repetition with `while`
#
# A `while` loop repeats while its condition remains true. The loop body must change a value that eventually makes the condition false.

# %% [markdown]
# ## Iterating over Dictionary Pairs
#
# `items()` supplies each dictionary key and value as a pair. Two loop variables unpack that pair.

# %% [markdown]
# ## Nested Loops
#
# A nested loop processes items inside grouped collections. The inner loop completes for each outer-loop item.

# %% [markdown]
# Keep a loop body short and name the changing value clearly. Prefer a suitable built-in operation when it already expresses the complete task, and use an explicit loop when the processing rule needs custom steps.
